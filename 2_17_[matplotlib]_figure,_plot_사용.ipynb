# %% [markdown]
# <a href="https://colab.research.google.com/github/GNuSeekK/ICTCOG/blob/main/2_17_%5Bmatplotlib%5D_figure%2C_plot_%EC%82%AC%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # colab 한글 꺠짐 방지

# %%
# !apt -qq -y install fonts-nanum > /dev/null

import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

fontpath = '/usr/share/fonts/truetype/nanum/NanumBarunGothic.ttf'
font = fm.FontProperties(fname=fontpath, size=10)
fm._rebuild()

# 그래프에 retina display 적용
# %config InlineBackend.figure_format = 'retina'

# Colab 의 한글 폰트 설정
plt.rc('font', family='NanumBarunGothic')
# Out:
# WARNING: apt does not have a stable CLI interface. Use with caution in scripts.

# %%
# 그래프 크기 고정
plt.rcParams['figure.figsize'] = (12,9)

# %% [markdown]
# # 1. 밑 그림 그리기

# %%
import numpy as np

# %% [markdown]
# ## 1 - 1. 단일 그래프

# %%
# 데이터 생성
data = np.arange(1,100)

# 그리기(plot)
plt.plot(data)

#그래프 보여주기
plt.show()

# %% [markdown]
# ## 1 - 2. 다중 그래프 (multiple graphs)
# 1개의 캔버스 안에 여러 개의 그래프를 그리는 것

# %%
data1 = np.arange(1, 51)
data2 = np.arange(51, 101)

plt.plot(data1)
plt.plot(data2)

plt.show()

# %% [markdown]
# 2개의 figure로 나누어서 다중 그래프 그리기
# * `plt.figuire()`를 활용하면 새로운 canvas를 만들어 낸다.

# %%
plt.plot(data1)

plt.figure() # 새로운 캔버스를 생성

plt.plot(data2)

plt.show()

# %% [markdown]
# ## 1 - 3. 여러개의 plot을 그리는 방법 (subplot)
# * subplot(row, column, index)

# %%
plt.subplot(2,1,1)
plt.plot(data1)
plt.subplot(2,1,2)
plt.plot(data2)
plt.show()

# %% [markdown]
# 위와 같은 그래프를 그리며 다른 표현
# * 콤마(,)를 생략하고 그리기

# %%
plt.subplot(211)
plt.plot(data1)

plt.subplot(212)
plt.plot(data2)

plt.show()

# %% [markdown]
# # 1-4. 여러개의 plot을 그리는 방법( subplots ) - s가 더 붙었음!
#
# `subplots(행의 개수, 열의 개수)`

# %%
# 밑 그림(figure) 설정
fig, axes = plt.subplots(2,3)

axes[0,0].plot(data1)
axes[0,1].plot(data1 * data1)
axes[0,2].plot(data1 ** 3)
axes[1,0].plot(data1 % 10)
axes[1,1].plot(-1 * data1)
axes[1,2].plot(data1 // 20)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 2. 주요 스타일 옵션

# %%
from IPython.display import Image

# 출처: matplotlib.org
Image('https://matplotlib.org/_images/anatomy.png')

# %% [markdown]
# ## 2 - 1. title
# 그래프의 제목

# %%
plt.plot(data1)
plt.plot(data2)

#plt.title('여기는 타이틀 입니다.')
plt.title('여기는 타이틀 입니다.', fontsize = 20)
plt.show()

# %% [markdown]
# ## 2 - 2. X, Y축 Label 설정

# %%
plt.plot(data1)
plt.plot(data2)

plt.title('label 설정 예제')

plt.xlabel('X축', fontsize=20)
plt.ylabel('Y축', fontsize=20)

plt.show()

# %% [markdown]
# ## 2 - 3. X, Y축 tick 설정 (rotation)

# %%
plt.plot(np.arange(10), np.arange(10) * 2)
plt.plot(np.arange(10), np.arange(10) ** 2)
plt.plot(np.arange(10), np.log(np.arange(10)))

# 타이틀 & font 설정
plt.title('X, Y 틱을 조정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## 2 - 4. 범례 (Legend) 설정

# %%
plt.plot(np.arange(10), np.arange(10) * 2)
plt.plot(np.arange(10), np.arange(10) ** 2)
plt.plot(np.arange(10), np.log(np.arange(10)))

# 타이틀 & font 설정
plt.title('X, Y 틱을 조정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

# legend 설정
plt.legend(['10 * 2', '10 ** 2', 'log'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## 2-5. X와 Y의 한계점 (Limit) 설정
# `xlim(), ylim()`

# %%
plt.plot(np.arange(10), np.arange(10) * 2)
plt.plot(np.arange(10), np.arange(10) ** 2)
plt.plot(np.arange(10), np.log(np.arange(10)))

# 타이틀 & font 설정
plt.title('X, Y 틱을 조정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

# legend 설정
plt.legend(['10 * 2', '10 ** 2', 'log'])

# x, y의 limit 설정
plt.xlim(0, 5)
plt.ylim(0.5, 10)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# ## 2 - 6. 스타일 세부 설정 market, line, color 설정
# **marker의 종류**
# * '.'	point marker
# * ','	pixel marker
# * 'o'	circle marker
# * 'v'	triangle_down marker
# * '^'	triangle_up marker
# * '<'	triangle_left marker
# * '>'	triangle_right marker
# * '1'	tri_down marker
# * '2'	tri_up marker
# * '3'	tri_left marker
# * '4'	tri_right marker
# * 's '	square marker
# * 'p'	pentagon marker
# * '*'	star marker
# * 'h'	hexagon1 marker
# * 'H'	hexagon2 marker
# * '+'	plus marker
# * 'x'	x marker
# * 'D'	diamond marker
# * 'd'	thin_diamond marker
# * '|'	vline marker
# * '_'	hline marker

# %%
plt.plot(np.arange(10), np.arange(10) * 2, marker='o', markersize = 5)
plt.plot(np.arange(10), np.arange(10) * 2 - 10, marker='H', markersize = 10)
plt.plot(np.arange(10), np.arange(10) * 2 - 20, marker='D', markersize = 15)
plt.plot(np.arange(10), np.arange(10) * 2 - 30, marker='*', markersize = 20)

# 타이틀 & font 설정
plt.title('마커 설정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# **line의 종류**
# * '-' solid line style
# * '--' dashed line style
# * '-.' dash-dot line style
# * ':' dotted line style

# %%
plt.plot(np.arange(10), np.arange(10) * 2, marker='o', linestyle='') # 선이없음
plt.plot(np.arange(10), np.arange(10) * 2 - 10, marker='H', linestyle='-') # 실선
plt.plot(np.arange(10), np.arange(10) * 2 - 20, marker='D', linestyle='--') # 짧은실선
plt.plot(np.arange(10), np.arange(10) * 2 - 30, marker='*', linestyle='-.') # 섞기
plt.plot(np.arange(10), np.arange(10) * 2 - 40, marker='*', linestyle=':') # 점선
# 타이틀 & font 설정
plt.title('라인 설정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# **color의 종류**
# * 'b'	blue
# * 'g'	green
# * 'r'	red
# * 'c'	cyan
# * 'm'	magenta
# * 'y'	yellow
# * 'k'	black
# * 'w'	white

# %%
plt.plot(np.arange(10), np.arange(10) * 2, marker='o', linestyle='', color = 'b') 
plt.plot(np.arange(10), np.arange(10) * 2 - 10, marker='H', linestyle='-', color = 'r') 
plt.plot(np.arange(10), np.arange(10) * 2 - 20, marker='D', linestyle='--', color = 'c') 
plt.plot(np.arange(10), np.arange(10) * 2 - 30, marker='*', linestyle='-.', color = 'y') 
# 타이틀 & font 설정
plt.title('색상 설정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# **투명도 설정**
# > `alpha` 옵션을 0~1 사이로 조절, 값이 작을 수록 투명

# %%
plt.plot(np.arange(10), np.arange(10) * 2, marker='o', color = 'b', alpha = 0.1) 
plt.plot(np.arange(10), np.arange(10) * 2 - 10, marker='H', color = 'r', alpha = 0.3) 
plt.plot(np.arange(10), np.arange(10) * 2 - 20, marker='D', color = 'c', alpha = 0.6) 
plt.plot(np.arange(10), np.arange(10) * 2 - 30, marker='*', color = 'y', alpha = 1.0) 
# 타이틀 & font 설정
plt.title('투명도(alpha) 설정')

# X축 & Y축 Label
plt.xlabel('X축')
plt.ylabel('Y축')

# X tick, Y tick 설정
plt.xticks(rotation=90)
plt.yticks(rotation=30)

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
